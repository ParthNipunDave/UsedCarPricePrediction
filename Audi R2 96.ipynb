# %% [markdown]
# ## Importing libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Reading data

# %%
data=pd.read_csv('audi.csv')
data.head()
# Out:
#   model  year  price transmission  mileage fuelType  tax   mpg  engineSize
# 0    A1  2017  12500       Manual    15735   Petrol  150  55.4         1.4
# 1    A6  2016  16500    Automatic    36203   Diesel   20  64.2         2.0
# 2    A1  2016  11000       Manual    29946   Petrol   30  55.4         1.4
# 3    A4  2017  16800    Automatic    25952   Diesel  145  67.3         2.0
# 4    A3  2019  17300       Manual     1998   Petrol  145  49.6         1.0

# %%
data.describe()
# Out:
#                year          price        mileage           tax           mpg  \
# count  10668.000000   10668.000000   10668.000000  10668.000000  10668.000000
# mean    2017.100675   22896.685039   24827.244001    126.011436     50.770022
# std        2.167494   11714.841888   23505.257205     67.170294     12.949782
# min     1997.000000    1490.000000       1.000000      0.000000     18.900000
# 25%     2016.000000   15130.750000    5968.750000    125.000000     40.900000
# 50%     2017.000000   20200.000000   19000.000000    145.000000     49.600000
# 75%     2019.000000   27990.000000   36464.500000    145.000000     58.900000
# max     2020.000000  145000.000000  323000.000000    580.000000    188.300000
#
#          engineSize
# count  10668.000000
# mean       1.930709
# std        0.602957
# min        0.000000
# 25%        1.500000
# 50%        2.000000
# 75%        2.000000
# max        6.300000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10668 entries, 0 to 10667
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   model         10668 non-null  object
#  1   year          10668 non-null  int64
#  2   price         10668 non-null  int64
#  3   transmission  10668 non-null  object
#  4   mileage       10668 non-null  int64
#  5   fuelType      10668 non-null  object
#  6   tax           10668 non-null  int64
#  7   mpg           10668 non-null  float64
#  8   engineSize    10668 non-null  float64
# dtypes: float64(2), int64(4), object(3)
# memory usage: 750.2+ KB

# %%
data.isna().sum()
# Out:
# model           0
# year            0
# price           0
# transmission    0
# mileage         0
# fuelType        0
# tax             0
# mpg             0
# engineSize      0
# dtype: int64

# %% [markdown]
# ## EDA

# %%
data.duplicated().sum()
# Out:
# 103

# %%
data.drop_duplicates(inplace=True)
data.duplicated().sum()
# Out:
# 0

# %%
data.plot(kind='box',subplots=True,layout=(3,2),figsize=(15,7))
# Out:
# year             AxesSubplot(0.125,0.657941;0.352273x0.222059)
# price         AxesSubplot(0.547727,0.657941;0.352273x0.222059)
# mileage          AxesSubplot(0.125,0.391471;0.352273x0.222059)
# tax           AxesSubplot(0.547727,0.391471;0.352273x0.222059)
# mpg                 AxesSubplot(0.125,0.125;0.352273x0.222059)
# engineSize       AxesSubplot(0.547727,0.125;0.352273x0.222059)
# dtype: object

# %% [markdown]
# ## Model

# %%
data['model'].nunique()
# Out:
# 26

# %%
data['model'].unique()
# Out:
# array([' A1', ' A6', ' A4', ' A3', ' Q3', ' Q5', ' A5', ' S4', ' Q2',
#        ' A7', ' TT', ' Q7', ' RS6', ' RS3', ' A8', ' Q8', ' RS4', ' RS5',
#        ' R8', ' SQ5', ' S8', ' SQ7', ' S3', ' S5', ' A2', ' RS7'],
#       dtype=object)

# %%
data['model'].value_counts()
# Out:
#  A3     1917
#  Q3     1379
#  A4     1375
#  A1     1337
#  A5      874
#  Q5      864
#  Q2      810
#  A6      748
#  Q7      394
#  TT      336
#  A7      122
#  A8      118
#  Q8       69
#  RS6      39
#  RS3      33
#  RS4      31
#  RS5      28
#  R8       28
#  S3       18
#  SQ5      16
#  S4       12
#  SQ7       8
#  S8        4
#  S5        3
#  A2        1
#  RS7       1
# Name: model, dtype: int64

# %%
plt.figure(figsize=(15,7))
sns.countplot(data=data,x='model')

# %%
plt.figure(figsize=(15,7))
sns.boxplot(data=data,x='model',y='price')

# %% [markdown]
# ### Year

# %%
data['year'].nunique()
# Out:
# 21

# %%
data['year'].unique()
# Out:
# array([2017, 2016, 2019, 2015, 2014, 2018, 2013, 2020, 2004, 2009, 2012,
#        2010, 2007, 2011, 2008, 2003, 2005, 2002, 2006, 1998, 1997],
#       dtype=int64)

# %%
data['year'].value_counts()
# Out:
# 2019    3139
# 2016    1959
# 2017    1932
# 2015     995
# 2018     860
# 2020     689
# 2014     446
# 2013     290
# 2012      85
# 2011      47
# 2010      32
# 2009      23
# 2008      21
# 2007      16
# 2006       9
# 2005       7
# 2003       6
# 2004       5
# 2002       2
# 1997       1
# 1998       1
# Name: year, dtype: int64

# %%
sns.distplot(data['year'])

# %%
sns.regplot(data=data,x='year',y='price')

# %%
plt.figure(figsize=(15,7))
sns.boxplot(data=data,x='year',y='price')

# %% [markdown]
# ### Price

# %%
data['price'].nunique()
# Out:
# 3260

# %%
sns.distplot(data['price'])

# %%
sns.boxplot(data=data,y='price')

# %% [markdown]
# ### Transmission

# %%
data['transmission'].nunique()
# Out:
# 3

# %%
data['transmission'].unique()
# Out:
# array(['Manual', 'Automatic', 'Semi-Auto'], dtype=object)

# %%
data['transmission'].value_counts()
# Out:
# Manual       4317
# Semi-Auto    3568
# Automatic    2680
# Name: transmission, dtype: int64

# %%
sns.countplot(data=data,x='transmission')

# %%
sns.boxplot(data=data,x='transmission',y='price')

# %% [markdown]
# ### Mileage

# %%
data['mileage'].nunique()
# Out:
# 7725

# %%
sns.distplot(data['mileage'])

# %%
sns.boxplot(data=data,y='mileage')

# %%
sns.regplot(data=data,x='mileage',y='price')

# %% [markdown]
# ### Fuel Type

# %%
data['fuelType'].nunique()
# Out:
# 3

# %%
data['fuelType'].unique()
# Out:
# array(['Petrol', 'Diesel', 'Hybrid'], dtype=object)

# %%
data['fuelType'].value_counts()
# Out:
# Diesel    5537
# Petrol    5000
# Hybrid      28
# Name: fuelType, dtype: int64

# %%
sns.countplot(data=data,x='fuelType')

# %%
sns.boxplot(data=data,x='fuelType',y='price')

# %% [markdown]
# ### Tax

# %%
data['tax'].nunique()
# Out:
# 37

# %%
sns.distplot(data['tax'])

# %%
sns.boxplot(data=data,y='tax')

# %%
sns.regplot(data=data,y='price',x='tax')

# %% [markdown]
# ### MPG

# %%
data['mpg'].nunique()
# Out:
# 104

# %%
sns.distplot(data['mpg'])

# %%
sns.boxplot(y=data['mpg'])

# %%
sns.regplot(data=data,x='mpg',y='price')

# %% [markdown]
# ### EngineSize

# %%
data['engineSize'].nunique()
# Out:
# 19

# %%
data['engineSize'].value_counts()
# Out:
# 2.0    5120
# 1.4    1589
# 3.0    1145
# 1.6     908
# 1.5     718
# 1.0     550
# 4.0     154
# 1.8     126
# 2.5      61
# 0.0      52
# 2.9      48
# 1.2      31
# 4.2      25
# 5.2      23
# 3.2       5
# 1.9       4
# 2.7       3
# 4.1       2
# 6.3       1
# Name: engineSize, dtype: int64

# %%
sns.countplot(data=data,x='engineSize')

# %%
sns.boxplot(y=data['engineSize'])

# %%
sns.regplot(data=data,x='engineSize',y='price')

# %% [markdown]
# ## Feature Engineering

# %%
from sklearn.preprocessing import LabelEncoder,MinMaxScaler,StandardScaler

# %%
minmax=MinMaxScaler()
le=LabelEncoder()
ss=StandardScaler()

# %%
cols=data.select_dtypes(include=['object']).columns
cols
# Out:
# Index(['model', 'transmission', 'fuelType'], dtype='object')

# %%
data[cols]=data[cols].apply(le.fit_transform)

# %%
sns.heatmap(data.corr(),annot=True,fmt='.2f')

# %%
from sklearn.feature_selection import SelectKBest,f_regression

# %%
feature=SelectKBest(score_func=f_regression,k='all').fit(data.drop('price',axis=1),data['price'])
feature=pd.DataFrame(data=feature.scores_,index=[data.drop('price',axis=1).columns])
feature.sort_values(by=0,ascending=False)
# Out:
#                         0
# mpg           5906.320650
# engineSize    5782.629922
# year          5705.177371
# mileage       4229.985986
# model         1933.899061
# tax           1529.190085
# fuelType        11.186559
# transmission     1.320824

# %%
cols=list(data.drop(['fuelType','transmission'],axis=1).columns)
cols.pop(2)
cols
# Out:
# ['model', 'year', 'mileage', 'tax', 'mpg', 'engineSize']

# %%
# data[cols]=minmax.fit_transform(data[cols])
data[cols]=ss.fit_transform(data[cols])
data.describe()
# Out:
#               model          year          price  transmission       mileage  \
# count  1.056500e+04  1.056500e+04   10565.000000  10565.000000  1.056500e+04
# mean  -6.440870e-16 -2.496661e-14   22853.956081      1.084051  1.565977e-16
# std    1.000047e+00  1.000047e+00   11723.076767      0.764446  1.000047e+00
# min   -1.119276e+00 -9.267472e+00    1490.000000      0.000000 -1.064276e+00
# 25%   -7.350931e-01 -5.004250e-01   15000.000000      0.000000 -8.084312e-01
# 50%   -3.509102e-01 -3.900153e-02   20000.000000      1.000000 -2.425794e-01
# 75%    6.095473e-01  8.838455e-01   27990.000000      2.000000  4.994935e-01
# max    3.683011e+00  1.345269e+00  145000.000000      2.000000  1.271094e+01
#
#            fuelType           tax           mpg    engineSize
# count  10565.000000  1.056500e+04  1.056500e+04  1.056500e+04
# mean       0.949172  4.681547e-15  5.753141e-16 -1.205472e-15
# std        0.997427  1.000047e+00  1.000047e+00  1.000047e+00
# min        0.000000 -1.867934e+00 -2.463800e+00 -3.206275e+00
# 25%        0.000000 -1.348752e-02 -7.666258e-01 -7.181891e-01
# 50%        0.000000  2.832239e-01 -9.547052e-02  1.111730e-01
# 75%        2.000000  2.832239e-01  6.219713e-01  1.111730e-01
# max        2.000000  6.736696e+00  1.060444e+01  7.243687e+00

# %% [markdown]
# ## Modeling

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_absolute_error,mean_squared_error

# %%
train_x,test_x,train_y,test_y=train_test_split(data[cols],data['price'],test_size=0.1,random_state=101)

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rfr=RandomForestRegressor(criterion='mae')
rfr.fit(train_x,train_y)
predict=rfr.predict(test_x)
print('MAE',mean_absolute_error(predict,test_y))
print('R2',r2_score(predict,test_y))
# Out:
# MAE 1540.6957190160833
# R2 0.9409285976584791

# %%
from xgboost import XGBRegressor

# %%
xgr=XGBRegressor(learning_rate=0.1,max_depth=10,n_estimators=100)
xgr.fit(train_x,train_y)
predict=xgr.predict(test_x)
print('MAE',mean_absolute_error(predict,test_y))
print('R2',r2_score(predict,test_y))
# Out:
# MAE 1468.7921644948854
# R2 0.9608937513922939

# %% [markdown]
# It gives delightful output
